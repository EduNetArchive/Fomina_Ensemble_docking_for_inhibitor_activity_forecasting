# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#Data was copied from dataframes, calculated with Chembl4495582_main. Sorry for the inconvenience
Set4_metrics = [[0.85,0.01,0.68,0.04,0.17,0.01,0.12,0.01,0.07,0.01,0.54,0.05],
                [0.99,0.00,0.69,0.06,0.67,0.05,0.19,0.04,0.18,0.04,0.21,0.05],
                [0.80,0.01,0.68,0.04,0.10,0.10,0.08,0.01,0.04,0.01,0.75,0.07]]

Set5_metrics = [[0.84,0.01,0.68,0.04,0.17,0.01,0.12,0.01,0.07,0.01,0.55,0.05],
[0.98,0.00,0.69,0.06,0.53,0.05,0.19,0.05,0.15,0.05,0.28,0.06],
[0.85,0.01,0.69,0.02,0.17,0.01,0.12,0.01,0.07,0.00,0.56,0.03]]

Set6_metrics = [[0.84,0.01,0.68,0.04,0.17,0.01,0.12,0.01,0.07,0.01,0.55,0.05],
[0.98,0.00,0.68,0.06,0.57,0.06,0.20,0.04,0.17,0.05,0.24,0.04],
[0.82,0.01,0.67,0.03,0.15,0.01,0.10,0.01,0.06,0.01,0.54,0.05]]
Set7_metrics = [[0.71,0.01,0.63,0.05,0.06,0.00,0.06,0.00,0.03,0.00,1.00,0.00],
[0.93,0.01,0.63,0.05,0.35,0.05,0.15,0.05,0.10,0.04,0.27,0.07],
[0.58,0.01,0.59,0.04,0.05,0.00,0.05,0.01,0.03,0.00,0.42,0.20]]
Set8_metrics = [[0.86,0.01,0.70,0.04,0.18,0.01,0.13,0.01,0.07,0.01,0.56,0.06],
[0.96,0.01,0.71,0.06,0.42,0.05,0.21,0.04,0.14,0.03,0.37,0.04],
[0.89,0.01,0.71,0.02,0.19,0.01,0.13,0.01,0.07,0.01,0.57,0.07]]
Set9_metrics = [[0.86,0.01,0.70,0.04,0.18,0.01,0.13,0.01,0.07,0.01,0.56,0.06],
[0.97,0.01,0.70,0.06,0.48,0.05,0.22,0.04,0.17,0.04,0.33,0.05],
[0.91,0.01,0.68,0.03,0.21,0.01,0.12,0.01,0.07,0.01,0.54,0.07]]

# %%
AUC_train_means_LR, AUC_train_std_LR = [Set4_metrics[0][0], Set5_metrics[0][0], Set6_metrics[0][0], Set7_metrics[0][0],
                            Set8_metrics[0][0], Set9_metrics[0][0]], [Set4_metrics[0][1], Set5_metrics[0][1], 
                            Set6_metrics[0][1], Set7_metrics[0][1], Set8_metrics[0][1], Set9_metrics[0][1]]
AUC_train_means_RF, AUC_train_std_RF = [Set4_metrics[1][0], Set5_metrics[1][0], Set6_metrics[1][0], Set7_metrics[1][0],
                            Set8_metrics[1][0], Set9_metrics[1][0]], [Set4_metrics[1][1], Set5_metrics[1][1], 
                            Set6_metrics[1][1], Set7_metrics[1][1], Set8_metrics[1][1], Set9_metrics[1][1]]
AUC_train_means_SVM, AUC_train_std_SVM = [Set4_metrics[2][0], Set5_metrics[2][0], Set6_metrics[2][0], Set7_metrics[2][0],
                            Set8_metrics[2][0], Set9_metrics[2][0]], [Set4_metrics[2][1], Set5_metrics[2][1], 
                            Set6_metrics[2][1], Set7_metrics[2][1], Set8_metrics[2][1], Set9_metrics[2][1]]

AUC_test_means_LR, AUC_test_std_LR = [Set4_metrics[0][2], Set5_metrics[0][2], Set6_metrics[0][2], Set7_metrics[0][2],
                            Set8_metrics[0][2], Set9_metrics[0][2]], [Set4_metrics[0][3], Set5_metrics[0][3], 
                            Set6_metrics[0][3], Set7_metrics[0][3], Set8_metrics[0][3], Set9_metrics[0][3]]
AUC_test_means_RF, AUC_test_std_RF = [Set4_metrics[1][2], Set5_metrics[1][2], Set6_metrics[1][2], Set7_metrics[1][2],
                            Set8_metrics[1][2], Set9_metrics[1][2]], [Set4_metrics[1][3], Set5_metrics[1][3], 
                            Set6_metrics[1][3], Set7_metrics[1][3], Set8_metrics[1][3], Set9_metrics[1][3]]
AUC_test_means_SVM, AUC_test_std_SVM = [Set4_metrics[2][2], Set5_metrics[2][2], Set6_metrics[2][2], Set7_metrics[2][2],
                            Set8_metrics[2][2], Set9_metrics[2][2]], [Set4_metrics[2][3], Set5_metrics[2][3], 
                            Set6_metrics[2][3], Set7_metrics[2][3], Set8_metrics[2][3], Set9_metrics[2][3]]

F1_train_means_LR, F1_train_std_LR = [Set4_metrics[0][4], Set5_metrics[0][4], Set6_metrics[0][4], Set7_metrics[0][4],
                            Set8_metrics[0][4], Set9_metrics[0][4]], [Set4_metrics[0][5], Set5_metrics[0][5], 
                            Set6_metrics[0][5], Set7_metrics[0][5], Set8_metrics[0][5], Set9_metrics[0][5]]
F1_train_means_RF, F1_train_std_RF = [Set4_metrics[1][4], Set5_metrics[1][4], Set6_metrics[1][4], Set7_metrics[1][4],
                            Set8_metrics[1][4], Set9_metrics[1][4]], [Set4_metrics[1][5], Set5_metrics[1][5], 
                            Set6_metrics[1][5], Set7_metrics[1][5], Set8_metrics[1][5], Set9_metrics[1][5]]
F1_train_means_SVM, F1_train_std_SVM = [Set4_metrics[2][4], Set5_metrics[2][4], Set6_metrics[2][4], Set7_metrics[2][4],
                            Set8_metrics[2][4], Set9_metrics[2][4]], [Set4_metrics[2][5], Set5_metrics[2][5], 
                            Set6_metrics[2][5], Set7_metrics[2][5], Set8_metrics[2][5], Set9_metrics[2][5]]

F1_test_means_LR, F1_test_std_LR = [Set4_metrics[0][6], Set5_metrics[0][6], Set6_metrics[0][6], Set7_metrics[0][6],
                            Set8_metrics[0][6], Set9_metrics[0][6]], [Set4_metrics[0][7], Set5_metrics[0][7], 
                            Set6_metrics[0][7], Set7_metrics[0][7], Set8_metrics[0][7], Set9_metrics[0][7]]
F1_test_means_RF, F1_test_std_RF = [Set4_metrics[1][6], Set5_metrics[1][6], Set6_metrics[1][6], Set7_metrics[1][6],
                            Set8_metrics[1][6], Set9_metrics[1][6]], [Set4_metrics[1][7], Set5_metrics[1][7], 
                            Set6_metrics[1][7], Set7_metrics[1][7], Set8_metrics[1][7], Set9_metrics[1][7]]
F1_test_means_SVM, F1_test_std_SVM = [Set4_metrics[2][6], Set5_metrics[2][6], Set6_metrics[2][6], Set7_metrics[2][6],
                            Set8_metrics[2][6], Set9_metrics[2][6]], [Set4_metrics[2][7], Set5_metrics[2][7], 
                            Set6_metrics[2][7], Set7_metrics[2][7], Set8_metrics[2][7], Set9_metrics[2][7]]

pre_test_means_LR, pre_test_std_LR = [Set4_metrics[0][8], Set5_metrics[0][8], Set6_metrics[0][8], Set7_metrics[0][8],
                            Set8_metrics[0][8], Set9_metrics[0][8]], [Set4_metrics[0][9], Set5_metrics[0][9], 
                            Set6_metrics[0][9], Set7_metrics[0][9], Set8_metrics[0][9], Set9_metrics[0][9]]
pre_test_means_RF, pre_test_std_RF = [Set4_metrics[1][8], Set5_metrics[1][8], Set6_metrics[1][8], Set7_metrics[1][8],
                            Set8_metrics[1][8], Set9_metrics[1][8]], [Set4_metrics[1][9], Set5_metrics[1][9], 
                            Set6_metrics[1][9], Set7_metrics[1][9], Set8_metrics[1][9], Set9_metrics[1][9]]
pre_test_means_SVM,pre_test_std_SVM = [Set4_metrics[2][8], Set5_metrics[2][8], Set6_metrics[2][8],Set7_metrics[2][8],
                            Set8_metrics[2][8], Set9_metrics[2][8]], [Set4_metrics[2][9], Set5_metrics[2][9], 
                            Set6_metrics[2][9], Set7_metrics[2][9], Set8_metrics[2][9], Set9_metrics[2][9]]

rec_test_means_LR, rec_test_std_LR = [Set4_metrics[0][10],Set5_metrics[0][10],Set6_metrics[0][10],Set7_metrics[0][10],
                            Set8_metrics[0][10], Set9_metrics[0][10]], [Set4_metrics[0][11], Set5_metrics[0][11], 
                            Set6_metrics[0][11], Set7_metrics[0][11], Set8_metrics[0][11], Set9_metrics[0][11]]
rec_test_means_RF, rec_test_std_RF = [Set4_metrics[1][10],Set5_metrics[1][10],Set6_metrics[1][10],Set7_metrics[1][10],
                            Set8_metrics[1][10], Set9_metrics[1][10]], [Set4_metrics[1][11], Set5_metrics[1][11], 
                            Set6_metrics[1][11], Set7_metrics[1][11], Set8_metrics[1][11], Set9_metrics[1][11]]
rec_test_means_SVM,rec_test_std_SVM = [Set4_metrics[2][10],Set5_metrics[2][10],Set6_metrics[2][10],Set7_metrics[2][10],
                            Set8_metrics[2][10], Set9_metrics[2][10]], [Set4_metrics[2][11], Set5_metrics[2][11], 
                            Set6_metrics[2][11], Set7_metrics[2][11], Set8_metrics[2][11], Set9_metrics[2][11]]

# %%
ind = np.arange(len(AUC_train_means_LR))  # the x locations for the groups
width = 0.25  # the width of the bars

fig, ax = plt.subplots(figsize = (3.14, 3), dpi = 300)
rects1 = ax.bar(ind - width, AUC_train_means_LR, width, yerr=AUC_train_std_LR,
                label='LR')
rects2 = ax.bar(ind, AUC_train_means_RF, width, yerr=AUC_train_std_RF,
                label='RF')
rects3 = ax.bar(ind + width, AUC_train_means_SVM, width, yerr=AUC_train_std_SVM,
                label='SVM')
ax.set_ylabel('ROC AUC')
#ax.set_title('Scores by Dataset and Model')
ax.set_xticks(ind)
ax.set_xticklabels(['M5F', 'M5', 'M5O', 'OIF', 'M1', 'M1O'])
#ax.legend()
fig.tight_layout()
plt.show()

# %%
ind = np.arange(len(AUC_train_means_LR))  # the x locations for the groups
width = 0.25  # the width of the bars

fig, ax = plt.subplots(figsize = (3.14, 3), dpi = 300)
plt.ylim(0,1.05)
rects1 = ax.bar(ind - width, AUC_test_means_LR, width, yerr=AUC_test_std_LR,
                label='LR')
rects2 = ax.bar(ind, AUC_test_means_RF, width, yerr=AUC_test_std_RF,
                label='RF')
rects3 = ax.bar(ind + width, AUC_test_means_SVM, width, yerr=AUC_test_std_SVM,
                label='SVM')
ax.set_ylabel('ROC AUC')
#ax.set_title('Scores by Dataset and Model')
ax.set_xticks(ind)
ax.set_xticklabels(['M5F', 'M5', 'M5O', 'OIF', 'M1', 'M1O'])
#ax.legend()
fig.tight_layout()

plt.show()

# %%
ind = np.arange(len(F1_train_means_LR))  # the x locations for the groups
width = 0.25  # the width of the bars

fig, ax = plt.subplots(figsize = (3.14, 3), dpi = 300)
plt.ylim(0,1.05)
rects1 = ax.bar(ind - width, F1_train_means_LR, width, yerr=F1_train_std_LR,
                label='LR')
rects2 = ax.bar(ind, F1_train_means_RF, width, yerr=F1_train_std_RF,
                label='RF')
rects3 = ax.bar(ind + width, F1_train_means_SVM, width, yerr=F1_train_std_SVM,
                label='SVM')
ax.set_ylabel('F1')
#ax.set_title('Scores by Dataset and Model')
ax.set_xticks(ind)
ax.set_xticklabels(['M5F', 'M5', 'M5O', 'OIF', 'M1', 'M1O'])
#ax.legend()
fig.tight_layout()

plt.show()

# %%
ind = np.arange(len(F1_train_means_LR))  # the x locations for the groups
width = 0.25  # the width of the bars

fig, ax = plt.subplots(figsize = (3.14, 3), dpi = 300)
plt.ylim(0,1.05)
rects1 = ax.bar(ind - width, F1_test_means_LR, width, yerr=F1_test_std_LR,
                label='LR')
rects2 = ax.bar(ind, F1_test_means_RF, width, yerr=F1_test_std_RF,
                label='RF')
rects3 = ax.bar(ind + width, F1_test_means_SVM, width, yerr=F1_test_std_SVM,
                label='SVM')
ax.set_ylabel('F1')
#ax.set_title('Scores by Dataset and Model')
ax.set_xticks(ind)
ax.set_xticklabels(['M5F', 'M5', 'M5O', 'OIF', 'M1', 'M1O'])
#ax.legend()
fig.tight_layout()

plt.show()

# %%
ind = np.arange(len(F1_train_means_LR))  # the x locations for the groups
width = 0.25  # the width of the bars

fig, ax = plt.subplots(figsize = (3.14, 3), dpi = 300)
plt.ylim(0,1.05)
rects1 = ax.bar(ind - width, pre_test_means_LR, width, yerr=pre_test_std_LR,
                label='LR')
rects2 = ax.bar(ind, pre_test_means_RF, width, yerr=pre_test_std_RF,
                label='RF')
rects3 = ax.bar(ind + width, pre_test_means_SVM, width, yerr=pre_test_std_SVM,
                label='SVM')
ax.set_ylabel('Precision 1')
#ax.set_title('Scores by Dataset and Model')
ax.set_xticks(ind)
ax.set_xticklabels(['M5F', 'M5', 'M5O', 'OIF', 'M1', 'M1O'])
#ax.legend()
fig.tight_layout()

plt.show()

# %%
ind = np.arange(len(F1_train_means_LR))  # the x locations for the groups
width = 0.25  # the width of the bars

fig, ax = plt.subplots(figsize = (3.14, 3), dpi = 300)
rects1 = ax.bar(ind - width, rec_test_means_LR, width, yerr=rec_test_std_LR,
                label='LR')
rects2 = ax.bar(ind, rec_test_means_RF, width, yerr=rec_test_std_RF,
                label='RF')
rects3 = ax.bar(ind + width, rec_test_means_SVM, width, yerr=rec_test_std_SVM,
                label='SVM')
ax.set_ylabel('Recall 1')
#ax.set_title('Scores by Dataset and Model')
ax.set_xticks(ind)
ax.set_xticklabels(['M5F', 'M5', 'M5O', 'OIF', 'M1', 'M1O'])
ax.legend()
fig.tight_layout()

plt.show()

# %%
AUC_train_mean_LR1, AUC_train_std_LR1 = [0.828,0.791,0.793,0.958,0.945,0.963,0.811,1.000,0.982],[0.011,0.010,
                                                            0.014,0.004,0.006,0.007,0.017,0.000,0.002]
AUC_test_mean_LR1, AUC_test_std_LR1 = [0.590,0.564,0.543,0.668,0.690, 0.687,0.603,0.680,0.712],[0.065,0.075,
                                                            0.068,0.047,0.034,0.031,0.027,0.044,0.033]
AUC_train_mean_RF1, AUC_train_std_RF1 = [0.961,0.966,0.981,0.990,0.985,0.983,0.942,0.969,0.972],[0.008,0.006,
                                                            0.005,0.003,0.003,0.004,0.011,0.005,0.006]
AUC_test_mean_RF1, AUC_test_std_RF1 = [0.632,0.637,0.619,0.687,0.687,0.682,0.628,0.703,0.699],[0.044,0.050,
                                                            0.054,0.056,0.060,0.062,0.049,0.060,0.057]
AUC_train_mean_CB1, AUC_train_std_CB1 = [1.000,0.938,0.917,0.998,0.996,0.956,0.974,0.995,0.992],[0.000,0.011,
                                                            0.010,0.001,0.002,0.008,0.008,0.002,0.003]
AUC_test_mean_CB1, AUC_test_std_CB1 = [0.548,0.614,0.607,0.664,0.679,0.659,0.585,0.690,0.631],[0.042,0.060,
                                                            0.056,0.022,0.060,0.053,0.053,0.047,0.063]
AUC_train_mean_SVM1, AUC_train_std_SVM1 = [0.765,0.320,0.322,0.881,0.754,0.820,0.570,0.864,0.910],[0.011,0.014,
                                                            0.014,0.007,0.013,0.010,0.009,0.015,0.009]
AUC_test_mean_SVM1, AUC_test_std_SVM1 = [0.576,0.449,0.467,0.684,0.627,0.666,0.581,0.642,0.684],[0.067,0.072,
                                                            0.069,0.017,0.036,0.027,0.034,0.032,0.032]
AUC_train_mean_TN1, AUC_train_std_TN1 = [0.979,0.995,0.994,0.998,0.994,0.996,0.962,0.999,0.999],[0.017,0.006,
                                                            0.006,0.003,0.008,0.008,0.095,0.002,0.002]
AUC_test_mean_TN1, AUC_test_std_TN1 = [0.850,0.748,0.749,0.785,0.752,0.848,0.712,0.815,0.815],[0.114,0.172,
                                                            0.118,0.155,0.146,0.115,0.147,0.133,0.133]

# %%
ind = np.arange(len(AUC_train_mean_LR1))  # the x locations for the groups
width = 0.175  # the width of the bars

fig, ax = plt.subplots(figsize = (3.14, 3), dpi = 300)
plt.ylim(0,1.1)
rects1 = ax.bar(ind - 2*width, AUC_train_mean_LR1, width, yerr=AUC_train_std_LR1,
                label='LR')
rects2 = ax.bar(ind-width, AUC_train_mean_RF1, width, yerr=AUC_train_std_RF1,
                label='RF')
rects3 = ax.bar(ind , AUC_train_mean_CB1, width, yerr=AUC_train_std_CB1,
                label='CatBoost')
rects4 = ax.bar(ind + width, AUC_train_mean_SVM1, width, yerr=AUC_train_std_SVM1,
                label='SVM')
rects5 = ax.bar(ind + 2*width, AUC_train_mean_TN1, width, yerr=AUC_train_std_TN1,
                label='TabNet')
ax.set_ylabel('ROC AUC')
#ax.set_title('Scores by Dataset and Model')
ax.set_xticks(ind)
ax.set_xticklabels(['OHF','FL','FLE','M5F', 'M5', 'M5O', 'OIF', 'M1', 'M1O'], fontsize=5)
#ax.legend()
fig.tight_layout()

plt.show()

# %%
ind = np.arange(len(AUC_train_mean_LR1))  # the x locations for the groups
width = 0.175  # the width of the bars

fig, ax = plt.subplots(figsize = (3.14, 3), dpi = 300)
plt.ylim(0,1.1)
rects1 = ax.bar(ind - 2*width, AUC_test_mean_LR1, width, yerr=AUC_test_std_LR1,
                label='LR')
rects2 = ax.bar(ind-width, AUC_test_mean_RF1, width, yerr=AUC_test_std_RF1,
                label='RF')
rects3 = ax.bar(ind , AUC_test_mean_CB1, width, yerr=AUC_test_std_CB1,
                label='CatBoost')
rects4 = ax.bar(ind + width, AUC_test_mean_SVM1, width, yerr=AUC_test_std_SVM1,
                label='SVM')
rects5 = ax.bar(ind + 2*width, AUC_test_mean_TN1, width, yerr=AUC_test_std_TN1,
                label='TabNet')
ax.set_ylabel('ROC AUC')
#ax.set_title('Scores by Dataset and Model')
ax.set_xticks(ind)
ax.set_xticklabels(['OHF','FL','FLE','M5F', 'M5', 'M5O', 'OIF', 'M1', 'M1O'], fontsize=5)
#ax.legend()
fig.tight_layout()

plt.show()

# %%
F1_train_mean_LR1, F1_train_std_LR1 = [0.155,0.138,0.137,0.305,0.277,0.311,0.147,0.872,0.385],[0.006,0.006,
                                                                0.009,0.010,0.012,0.019,0.009,0.010,0.011]
F1_test_mean_LR1, F1_test_std_LR1 = [0.082,0.074,0.070,0.114,0.135,0.139,0.081,0.209,0.179],[0.026,0.020,
                                                                0.017,0.029,0.017,0.015,0.016,0.029,0.022]
F1_train_mean_RF1, F1_train_std_RF1 = [0.438,0.465,0.592,0.655,0.576,0.581,0.401,0.453,0.499],[0.057,0.043,
                                                                0.055,0.060,0.054,0.053,0.061,0.045,0.058]
F1_test_mean_RF1, F1_test_std_RF1 = [0.124,0.125,0.120,0.188,0.200,0.200,0.145,0.212,0.208],[0.027,0.032,
                                                                0.051,0.045,0.061,0.035,0.048,0.039,0.034]
F1_train_mean_CB1, F1_train_std_CB1 = [0.013,0.380,0.189,0.847,0.735,0.397,0.597,0.688,0.678],[0.012,0.030,
                                                                0.020,0.035,0.019,0.037,0.036,0.025,0.033]
F1_test_mean_CB1, F1_test_std_CB1 = [0.000,0.026,0.000,0.087,0.082,0.033,0.051,0.096,0.069],[0.000,0.039,
                                                                0.000,0.067,0.050,0.041,0.043,0.046,0.051]
F1_train_mean_SVM1, F1_train_std_SVM1 = [0.115,0.000,0.000,0.184,0.138,0.154,0.000,0.197,0.208],[0.003,0.000,
                                                                0.000,0.008,0.006,0.008,0.000,0.011,0.010]
F1_test_mean_SVM1, F1_test_std_SVM1 = [0.073,0.000,0.000,0.119,0.090,0.581,0.000,0.106,0.124],[0.019,0.000,
                                                                0.000,0.016,0.013,0.034,0.000,0.011,0.013]
F1_train_mean_TN1, F1_train_std_TN1 = [0.813,0.947,0.931,0.971,0.953,0.965,0.860,0.974,0.974],[0.084,0.072,
                                                                0.096,0.015,0.020,0.058,0.300,0.011,0.011]
F1_test_mean_TN1, F1_test_std_TN1 = [0.232,0.464,0.433,0.520,0.527,0.628,0.392,0.623,0.623],[0.087,0.267,
                                                                0.239,0.252,0.223,0.294,0.270,0.221,0.221]

# %%
ind = np.arange(len(AUC_train_mean_LR1))  # the x locations for the groups
width = 0.175  # the width of the bars

fig, ax = plt.subplots(figsize = (3.14, 3), dpi = 300)
#plt.ylim(0,1)
rects1 = ax.bar(ind - 2*width, F1_train_mean_LR1, width, yerr=F1_train_std_LR1,
                label='LR')
rects2 = ax.bar(ind-width, F1_train_mean_RF1, width, yerr=F1_train_std_RF1,
                label='RF')
rects3 = ax.bar(ind , F1_train_mean_CB1, width, yerr=F1_train_std_CB1,
                label='CatBoost')
rects4 = ax.bar(ind + width, F1_train_mean_SVM1, width, yerr=F1_train_std_SVM1,
                label='SVM')
rects5 = ax.bar(ind + 2*width, F1_train_mean_TN1, width, yerr=F1_train_std_TN1,
                label='TabNet')
ax.set_ylabel('F1')
#ax.set_title('Scores by Dataset and Model')
ax.set_xticks(ind)
ax.set_xticklabels(['OHF','FL','FLE','M5F', 'M5', 'M5O', 'OIF', 'M1', 'M1O'], fontsize=5)
#ax.legend()
fig.tight_layout()

plt.show()

# %%
ind = np.arange(len(AUC_train_mean_LR1))  # the x locations for the groups
width = 0.175  # the width of the bars

fig, ax = plt.subplots(figsize = (3.14, 3), dpi = 300)
plt.ylim(0,1.22)
rects1 = ax.bar(ind - 2*width, F1_test_mean_LR1, width, yerr=F1_test_std_LR1,
                label='LR')
rects2 = ax.bar(ind-width, F1_test_mean_RF1, width, yerr=F1_test_std_RF1,
                label='RF')
rects3 = ax.bar(ind , F1_test_mean_CB1, width, yerr=F1_test_std_CB1,
                label='CatBoost')
rects4 = ax.bar(ind + width, F1_test_mean_SVM1, width, yerr=F1_test_std_SVM1,
                label='SVM')
rects5 = ax.bar(ind + 2*width, F1_test_mean_TN1, width, yerr=F1_test_std_TN1,
                label='TabNet')
ax.set_ylabel('F1')
#ax.set_title('Scores by Dataset and Model')
ax.set_xticks(ind)
ax.set_xticklabels(['OHF','FL','FLE','M5F', 'M5', 'M5O', 'OIF', 'M1', 'M1O'], fontsize=5)
ax.legend(loc=2, fontsize=5)
fig.tight_layout()

plt.show()

# %%
pre_test_mean_CB1, pre_test_std_CB1 = [0.63,0.11,0.64,0.49,0.71,0.61,0.60,0.55],[0.43,0.31,
                                                                0.34,0.18,0.27,0.37,0.34,0.22]
rec_test_mean_CB1, rec_test_std_CB1 = [0.03,0.00,0.05,0.06,0.04,0.04,0.05,0.07],[0.02,0.01,
                                                                0.03,0.04,0.01,0.02,0.03,0.04]
pre_test_mean_LR1, pre_test_std_LR1 = [0.04,0.04,0.09,0.08,0.09,0.06,0.11,0.11],[0.01,0.01,
                                                                0.01,0.01,0.01,0.01,0.01,0.01]
rec_test_mean_LR1, rec_test_std_LR1 = [0.44,0.40,0.44,0.47,0.47,0.51,0.47,0.46],[0.09,0.10,
                                                                0.05,0.05,0.06,0.08,0.06,0.06]
pre_test_mean_RF1, pre_test_std_RF1 = [0.10,0.11,0.17,0.15,0.17,0.10,0.15,0.17],[0.02,0.05,
                                                                0.04,0.05,0.05,0.04,0.04,0.04]
rec_test_mean_RF1, rec_test_std_RF1 = [0.20,0.15,0.21,0.26,0.24,0.24,0.35,0.33],[0.04,0.07,
                                                                0.06,0.06,0.04,0.06,0.05,0.05]
pre_test_mean_SVM1, pre_test_std_SVM1 = [0.00,0.00,0.07,0.05,0.06,0.00,0.06,0.07],[0.00,0.00,
                                                                0.01,0.01,0.01,0.00,0.01,0.01]
rec_test_mean_SVM1, rec_test_std_SVM1 = [0.00,0.00,0.55,0.53,0.54,0.00,0.50,0.54],[0.00,0.00,
                                                                0.06,0.06,0.05,0.00,0.06,0.07]

# %%
ind = np.arange(len(pre_test_mean_LR1))  # the x locations for the groups
width = 0.175  # the width of the bars

fig, ax = plt.subplots(figsize = (3.14, 3), dpi = 300)
plt.ylim(0,1.22)
rects1 = ax.bar(ind - 1.5*width, pre_test_mean_LR1, width, yerr=pre_test_std_LR1,
                label='LR')
rects2 = ax.bar(ind-0.5*width, pre_test_mean_RF1, width, yerr=pre_test_std_RF1,
                label='RF')
rects3 = ax.bar(ind+0.5*width , pre_test_mean_CB1, width, yerr=pre_test_std_CB1,
                label='CatBoost')
rects4 = ax.bar(ind + 1.5*width, pre_test_mean_SVM1, width, yerr=pre_test_std_SVM1,
                label='SVM')

ax.set_ylabel('Precision 1')
#ax.set_title('Scores by Dataset and Model')
ax.set_xticks(ind)
ax.set_xticklabels(['FL','FLE','M5F', 'M5', 'M5O', 'OIF', 'M1', 'M1O'], fontsize=5)
#ax.legend(fontsize=5)
fig.tight_layout()

plt.show()

# %%
ind = np.arange(len(pre_test_mean_LR1))  # the x locations for the groups
width = 0.175  # the width of the bars

fig, ax = plt.subplots(figsize = (3.14, 3), dpi = 300)
plt.ylim(0,1.22)
rects1 = ax.bar(ind - 1.5*width, rec_test_mean_LR1, width, yerr=rec_test_std_LR1,
                label='LR')
rects2 = ax.bar(ind-0.5*width, rec_test_mean_RF1, width, yerr=rec_test_std_RF1,
                label='RF')
rects3 = ax.bar(ind+0.5*width , rec_test_mean_CB1, width, yerr=rec_test_std_CB1,
                label='CatBoost')
rects4 = ax.bar(ind + 1.5*width, rec_test_mean_SVM1, width, yerr=rec_test_std_SVM1,
                label='SVM')

ax.set_ylabel('Recall 1')
#ax.set_title('Scores by Dataset and Model')
ax.set_xticks(ind)
ax.set_xticklabels(['FL','FLE','M5F', 'M5', 'M5O', 'OIF', 'M1', 'M1O'], fontsize=5)
ax.legend(fontsize=5)
fig.tight_layout()

plt.show()

# %% [markdown]
# # Ensemble models

# %%
AUC_train_means_LR, AUC_train_std_LR = [0.74,0.81,0.81], []
AUC_train_means_RF, AUC_train_std_RF = [0.87,0.89,0.9], []
AUC_train_means_SVM, AUC_train_std_SVM = [0.31,0.78,0.81], []

AUC_test_means_LR, AUC_test_std_LR = [0.66,0.7,0.7], []
AUC_test_means_RF, AUC_test_std_RF = [0.69,0.74,0.75], []
AUC_test_means_SVM, AUC_test_std_SVM = [0.3,0.69,0.7], []

F1_train_means_LR, F1_train_std_LR = [0.06,0.11,0.11], []
F1_train_means_RF, F1_train_std_RF = [0.2,0.14,0.15], []
F1_train_means_SVM, F1_train_std_SVM = [0,0.16,0.17], []

F1_test_means_LR, F1_test_std_LR = [0.06,0.1,0.1], []
F1_test_means_RF, F1_test_std_RF = [0.14,0.11,0.12], []
F1_test_means_SVM, F1_test_std_SVM = [0,0.1,0.11], []

lift_train_means_LR, lift_train_std_LR = [1.01,1.87,1.9], []
lift_train_means_RF, lift_train_std_RF = [3.62,2.44,2.55], []
lift_train_means_SVM, lift_train_std_SVM = [0,3.04,3.03], []

lift_test_means_LR, lift_test_std_LR = [1,1.76,1.76], []
lift_test_means_RF, lift_test_std_RF = [2.45,1.82,1.98], []
lift_test_means_SVM, lift_test_std_SVM = [0,1.96,1.99], []

pre_test_means_LR, pre_test_std_LR = [0.03,0.06,0.06], []
pre_test_means_RF, pre_test_std_RF = [0.08,0.06,0.06], []
pre_test_means_SVM,pre_test_std_SVM = [0,0.06,0.06], []

rec_test_means_LR, rec_test_std_LR = [1,0.81,0.89], []
rec_test_means_RF, rec_test_std_RF = [0.53,0.69,0.72], []
rec_test_means_SVM,rec_test_std_SVM = [0,0.31,0.44], []

# %%
ind = np.arange(len(AUC_train_means_LR))  # the x locations for the groups
width = 0.25  # the width of the bars

fig, ax = plt.subplots(figsize = (3.14, 3), dpi = 300)
plt.ylim(0,1.05)
rects1 = ax.bar(ind - width, AUC_train_means_LR, width,
                label='LR')
rects2 = ax.bar(ind, AUC_train_means_RF, width,
                label='RF')
rects3 = ax.bar(ind + width, AUC_train_means_SVM, width, 
                label='SVM')
ax.set_ylabel('ROC AUC')
#ax.set_title('Scores by Dataset and Model')
ax.set_xticks(ind)
ax.set_xticklabels(['OIF', 'M1', 'M1O'])
#ax.legend()
fig.tight_layout()

plt.show()

# %%
ind = np.arange(len(AUC_train_means_LR))  # the x locations for the groups
width = 0.25  # the width of the bars

fig, ax = plt.subplots(figsize = (3.14, 3), dpi = 300)
plt.ylim(0,1.05)
rects1 = ax.bar(ind - width, AUC_test_means_LR, width,
                label='LR')
rects2 = ax.bar(ind, AUC_test_means_RF, width,
                label='RF')
rects3 = ax.bar(ind + width, AUC_test_means_SVM, width, 
                label='SVM')
ax.set_ylabel('ROC AUC')
#ax.set_title('Scores by Dataset and Model')
ax.set_xticks(ind)
ax.set_xticklabels(['OIF', 'M1', 'M1O'])
#ax.legend()
fig.tight_layout()
plt.show()

# %%
ind = np.arange(len(AUC_train_means_LR))  # the x locations for the groups
width = 0.25  # the width of the bars

fig, ax = plt.subplots(figsize = (3.14, 3), dpi = 300)
plt.ylim(0,1.05)
rects1 = ax.bar(ind - width, F1_train_means_LR, width,
                label='LR')
rects2 = ax.bar(ind, F1_train_means_RF, width,
                label='RF')
rects3 = ax.bar(ind + width, F1_train_means_SVM, width, 
                label='SVM')
ax.set_ylabel('F1')
#ax.set_title('Scores by Dataset and Model')
ax.set_xticks(ind)
ax.set_xticklabels(['OIF', 'M1', 'M1O'])
#ax.legend()
fig.tight_layout()
plt.show()

# %%
ind = np.arange(len(AUC_train_means_LR))  # the x locations for the groups
width = 0.25  # the width of the bars

fig, ax = plt.subplots(figsize = (3.14, 3), dpi = 300)
plt.ylim(0,1.05)
rects1 = ax.bar(ind - width, F1_test_means_LR, width,
                label='LR')
rects2 = ax.bar(ind, F1_test_means_RF, width,
                label='RF')
rects3 = ax.bar(ind + width, F1_test_means_SVM, width, 
                label='SVM')
ax.set_ylabel('F1')
#ax.set_title('Scores by Dataset and Model')
ax.set_xticks(ind)
ax.set_xticklabels(['OIF', 'M1', 'M1O'])
ax.legend()
fig.tight_layout()

plt.show()

# %%
ind = np.arange(len(AUC_train_means_LR))  # the x locations for the groups
width = 0.25  # the width of the bars

fig, ax = plt.subplots(figsize = (3.14, 3), dpi = 300)
plt.ylim(0,1.05)
rects1 = ax.bar(ind - width, pre_test_means_LR, width,
                label='LR')
rects2 = ax.bar(ind, pre_test_means_RF, width,
                label='RF')
rects3 = ax.bar(ind + width, pre_test_means_SVM, width, 
                label='SVM')
ax.set_ylabel('Precision 1')
#ax.set_title('Scores by Dataset and Model')
ax.set_xticks(ind)
ax.set_xticklabels(['OIF', 'M1', 'M1O'])
ax.legend()
fig.tight_layout()
plt.show()

# %%
ind = np.arange(len(AUC_train_means_LR))  # the x locations for the groups
width = 0.25  # the width of the bars

fig, ax = plt.subplots(figsize = (3.14, 3), dpi = 300)
plt.ylim(0,1.05)
rects1 = ax.bar(ind - width, rec_test_means_LR, width,
                label='LR')
rects2 = ax.bar(ind, rec_test_means_RF, width,
                label='RF')
rects3 = ax.bar(ind + width, rec_test_means_SVM, width, 
                label='SVM')
ax.set_ylabel('Recall 1')
#ax.set_title('Scores by Dataset and Model')
ax.set_xticks(ind)
ax.set_xticklabels(['OIF', 'M1', 'M1O'])
#ax.legend()
fig.tight_layout()

plt.show()
